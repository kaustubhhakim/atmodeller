# %% [markdown]
# # atmodeller
#
# ## Tutorial 2: planet properties
#
# Import the required packages and set the package logger to the INFO level. For more output you could instead set it to DEBUG.

# %%
from atmodeller import Planet, logger
from atmodeller import InteriorAtmosphereSystem, SystemConstraint, OCEAN_MOLES, MolarMasses, MassConstraint, FugacityConstraint
from atmodeller.thermodynamics import PeridotiteH2O, ChemicalComponent, NoSolubility, BasaltDixonCO2, IronWustiteBufferFischer, GasSpecies
import logging

logger.setLevel(logging.DEBUG)
# Out:
# 21:50:19 - atmodeller                     - INFO      - atmodeller version 0.1.0

# %% [markdown]
# ### 1. Creating a planet

# %%
planet: Planet = Planet()
# Out:
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Creating a new planet
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Mantle mass (kg) = 4208261222595110885130240.000000
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Mantle melt fraction = 1.000000
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Core mass fraction = 0.295335
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Planetary radius (m) = 6371000.000000
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Planetary mass (kg) = 5972000000000000327155712.000000
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Surface temperature (K) = 2000.000000
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Surface gravity (m/s^2) = 9.819973
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Melt Composition = None

# %% [markdown]
# We can also query for the properties of the planet:

# %%
planet
# Out:
# Planet(mantle_mass=4.208261222595111e+24, mantle_melt_fraction=1.0, core_mass_fraction=0.295334691460966, surface_radius=6371000.0, surface_temperature=2000.0, melt_composition=None, planet_mass=5.972e+24, surface_gravity=9.819973426224687)

# %% [markdown]
# We will create a new planet with some different properties to the default:

# %%
surface_temperature: float = 2500 # K
mantle_melt_fraction: float = 0.9

planet = Planet(surface_temperature=surface_temperature, mantle_melt_fraction=mantle_melt_fraction, melt_composition='Basalt')
planet
# Out:
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Creating a new planet
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Mantle mass (kg) = 4208261222595110885130240.000000
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Mantle melt fraction = 0.900000
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Core mass fraction = 0.295335
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Planetary radius (m) = 6371000.000000
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Planetary mass (kg) = 5972000000000000327155712.000000
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Surface temperature (K) = 2500.000000
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Surface gravity (m/s^2) = 9.819973
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Melt Composition = Basalt
# Planet(mantle_mass=4.208261222595111e+24, mantle_melt_fraction=0.9, core_mass_fraction=0.295334691460966, surface_radius=6371000.0, surface_temperature=2500, melt_composition='Basalt', planet_mass=5.972e+24, surface_gravity=9.819973426224687)

# %% [markdown]
# Similar to tutorial 1, we can now construct an interior-atmosphere system for our new planet:

# %%
molecules: list[ChemicalComponent] = []
molecules.append(GasSpecies(chemical_formula='H2O', solid_melt_distribution_coefficient=0))
molecules.append(GasSpecies(chemical_formula='H2',  solid_melt_distribution_coefficient=0))
molecules.append(GasSpecies(chemical_formula='O2',  solid_melt_distribution_coefficient=0))
# molecules.append(Molecule(chemical_formula='CO',  solid_melt_distribution_coefficient=0))
# molecules.append(Molecule(chemical_formula='CO2', solid_melt_distribution_coefficient=0))

# molecules.append(Molecule(chemical_formula='Cl2', solid_melt_distribution_coefficient=0))
# molecules.append(Molecule(chemical_formula='N2', solid_melt_distribution_coefficient=0))
# molecules.append(Molecule(chemical_formula='HCl', solid_melt_distribution_coefficient=0))
# molecules.append(Molecule(chemical_formula='H2S', solubility=NoSolubility(), solid_melt_distribution_coefficient=0))
# molecules.append(Molecule(chemical_formula='S', solubility=NoSolubility(), solid_melt_distribution_coefficient=0))
# molecules.append(Molecule(chemical_formula='C', solubility=NoSolubility(), solid_melt_distribution_coefficient=0))

molecules
# Out:
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Creating a GasSpecies: H2O (H2O)
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - element count =
# {'H': 2, 'O': 1}
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - Hill formula string (required for JANAF) = H2O
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Creating a GasSpecies: H2 (H2)
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - element count =
# {'H': 2}
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - Hill formula string (required for JANAF) = H2
# 21:50:19 - atmodeller.thermodynamics      - INFO      - Creating a GasSpecies: O2 (O2)
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - element count =
# {'O': 2}
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - Hill formula string (required for JANAF) = O2
# [GasSpecies(chemical_formula='H2O', common_name='H2O', elements={'H': 2, 'O': 1}, element_masses={'H': 0.0020158, 'O': 0.0159994}, hill_formula='H2O', molar_mass=0.018015200000000002, solubility=<atmodeller.thermodynamics.NoSolubility object at 0x126d76a50>, solid_melt_distribution_coefficient=0),
#  GasSpecies(chemical_formula='H2', common_name='H2', elements={'H': 2}, element_masses={'H': 0.0020158}, hill_formula='H2', molar_mass=0.0020158, solubility=<atmodeller.thermodynamics.NoSolubility object at 0x10fea9590>, solid_melt_distribution_coefficient=0),
#  GasSpecies(chemical_formula='O2', common_name='O2', elements={'O': 2}, element_masses={'O': 0.0319988}, hill_formula='O2', molar_mass=0.0319988, solubility=<atmodeller.thermodynamics.NoSolubility object at 0x126b9dd90>, solid_melt_distribution_coefficient=0)]

# %% [markdown]
# Only now we pass in our planet as an argument when we construct the interior-atmosphere system:

# %%
interior_atmosphere: InteriorAtmosphereSystem = InteriorAtmosphereSystem(molecules=molecules, planet=planet)
# Out:
# 21:50:19 - atmodeller.core                - INFO      - Creating a new interior-atmosphere system
# 21:50:19 - atmodeller.core                - INFO      - Molecules = ['H2', 'O2', 'H2O']
# 21:50:19 - atmodeller.core                - INFO      - Setting solubilities to be consistent with the melt composition (Basalt)
# 21:50:19 - atmodeller.core                - INFO      - Found Solubility for H2: BasaltH2
# 21:50:19 - atmodeller.core                - INFO      - No solubility for O2
# 21:50:19 - atmodeller.core                - INFO      - Found Solubility for H2O: BasaltDixonH2O
# 21:50:19 - atmodeller.core                - INFO      - Molecules = ['H2', 'O2', 'H2O']
# 21:50:19 - atmodeller.core                - DEBUG     - number of unique elements =
# ['H', 'O']
# 21:50:19 - atmodeller.core                - DEBUG     - augmented_matrix =
# [[2. 0. 1. 0. 0.]
#  [0. 2. 0. 1. 0.]
#  [2. 1. 0. 0. 1.]]
# 21:50:19 - atmodeller.core                - DEBUG     - ratio =
# 0.0
# 21:50:19 - atmodeller.core                - DEBUG     - ratio =
# 1.0
# 21:50:19 - atmodeller.core                - DEBUG     - ratio =
# 0.5
# 21:50:19 - atmodeller.core                - DEBUG     - augmented_matrix after forward elimination =
# [[ 2.   0.   1.   0.   0. ]
#  [ 0.   2.   0.   1.   0. ]
#  [ 0.   0.  -1.  -0.5  1. ]]
# 21:50:19 - atmodeller.core                - DEBUG     - augmented_matrix after backward substitution =
# [[ 1.   0.   0.5  0.   0. ]
#  [ 0.   1.   0.   0.5  0. ]
#  [ 0.   0.  -1.  -0.5  1. ]]
# 21:50:19 - atmodeller.core                - DEBUG     - reduced_matrix1 =
# [[1. 0.]
#  [0. 1.]
#  [0. 0.]]
# 21:50:19 - atmodeller.core                - DEBUG     - reaction_matrix =
# [[-1.  -0.5  1. ]]
# 21:50:19 - atmodeller.core                - INFO      - Reactions =
# {0: '1.0 H2 + 0.5 O2 = 1.0 H2O'}

# %% [markdown]
# Solve the system with constraints:

# %%
number_of_earth_oceans: float = 1
# C/H ratio by mass.
ch_ratio: float = 1

mass_H: float = number_of_earth_oceans * OCEAN_MOLES * MolarMasses().H2
# mass_C: float = ch_ratio * mass_H
# mass_Cl: float = 0.01*mass_H
constraints: list[SystemConstraint] = [
    MassConstraint(species="H", value=mass_H),
    # MassConstraint(species="C", value=mass_C),
    ##SystemConstraint(species="Cl", value=mass_Cl, field="mass"),
    FugacityConstraint(species='H2O', value=0.5)
]

interior_atmosphere.solve(constraints)
interior_atmosphere.fugacities_dict
# Out:
# 21:50:19 - atmodeller.core                - INFO      - Constraints: [MassConstraint(species='H', value=1.5499384884020874e+20, field='mass'),
#  FugacityConstraint(species='H2O', value=0.5, field='fugacity')]
# 21:50:19 - atmodeller.core                - INFO      - Mixed pressure and mass constraints so attempting to solve a non-linear system of equations
# 21:50:19 - atmodeller.core                - DEBUG     - initial_log10_pressures = [1. 1. 1.]
# 21:50:19 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:19 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126b8f490>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dde350>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e1be50>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:19 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:19 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:19 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:19 - atmodeller.core                - DEBUG     - residual_reaction = [-2.72339717  1.30103   ]
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 10.000000, T = 2500.000000, ppmw = 42.167252
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 10.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 10.000000, T = 2500.000000, ppmw = 3051.597942
# 21:50:19 - atmodeller.core                - DEBUG     - residual_mass = [8.45215049]
# 21:50:19 - atmodeller.core                - DEBUG     - residual = [-2.72339717  1.30103     8.45215049]
# 21:50:19 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:19 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dd23d0>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126da71d0>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:19 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e3f890>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:20 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:20 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:20 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:20 - atmodeller.core                - DEBUG     - residual_reaction = [-2.72339717  1.30103   ]
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 10.000000, T = 2500.000000, ppmw = 42.167252
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 10.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 10.000000, T = 2500.000000, ppmw = 3051.597942
# 21:50:20 - atmodeller.core                - DEBUG     - residual_mass = [8.45215049]
# 21:50:20 - atmodeller.core                - DEBUG     - residual = [-2.72339717  1.30103     8.45215049]
# 21:50:20 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:20 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126bed290>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x107631e50>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dd0990>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:20 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:20 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:20 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:20 - atmodeller.core                - DEBUG     - residual_reaction = [-2.72339717  1.30103   ]
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 10.000000, T = 2500.000000, ppmw = 42.167252
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 10.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 10.000000, T = 2500.000000, ppmw = 3051.597942
# 21:50:20 - atmodeller.core                - DEBUG     - residual_mass = [8.45215049]
# 21:50:20 - atmodeller.core                - DEBUG     - residual = [-2.72339717  1.30103     8.45215049]
# 21:50:20 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:20 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dd48d0>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e22e90>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126d95ad0>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:20 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:20 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:20 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:20 - atmodeller.core                - DEBUG     - residual_reaction = [-2.72339718  1.30103   ]
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 10.000000, T = 2500.000000, ppmw = 42.167253
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 10.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 10.000000, T = 2500.000000, ppmw = 3051.597942
# 21:50:20 - atmodeller.core                - DEBUG     - residual_mass = [8.45215051]
# 21:50:20 - atmodeller.core                - DEBUG     - residual = [-2.72339718  1.30103     8.45215051]
# 21:50:20 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:20 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e07f50>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dbfbd0>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126df1750>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:20 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:20 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:20 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:20 - atmodeller.core                - DEBUG     - residual_reaction = [-2.72339717  1.30103   ]
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 10.000000, T = 2500.000000, ppmw = 42.167252
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 10.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 10.000000, T = 2500.000000, ppmw = 3051.597942
# 21:50:20 - atmodeller.core                - DEBUG     - residual_mass = [8.45215049]
# 21:50:20 - atmodeller.core                - DEBUG     - residual = [-2.72339717  1.30103     8.45215049]
# 21:50:20 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:20 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dbd190>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e27450>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dd4810>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:20 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:20 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:20 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:20 - atmodeller.core                - DEBUG     - residual_reaction = [-2.72339715  1.30103001]
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 10.000000, T = 2500.000000, ppmw = 42.167252
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 10.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 10.000000, T = 2500.000000, ppmw = 3051.597994
# 21:50:20 - atmodeller.core                - DEBUG     - residual_mass = [8.45215064]
# 21:50:20 - atmodeller.core                - DEBUG     - residual = [-2.72339715  1.30103001  8.45215064]
# 21:50:20 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:20 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e25550>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e4bed0>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dcb790>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:20 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:20 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:20 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:20 - atmodeller.core                - DEBUG     - residual_reaction = [ 5.93969318e-12 -2.83800761e-12]
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 3338.130455, T = 2500.000000, ppmw = 886.426040
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 0.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.500000, T = 2500.000000, ppmw = 682.358044
# 21:50:20 - atmodeller.core                - DEBUG     - residual_mass = [134.27781571]
# 21:50:20 - atmodeller.core                - DEBUG     - residual = [ 5.93969318e-12 -2.83800761e-12  1.34277816e+02]
# 21:50:20 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:20 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dd1610>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e16a90>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e15bd0>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:20 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:20 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:20 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:20 - atmodeller.core                - DEBUG     - residual_reaction = [-1.95354191  0.95252319]
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.002435, T = 2500.000000, ppmw = 0.538274
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 977814.736665, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 4.482220, T = 2500.000000, ppmw = 2043.026070
# 21:50:20 - atmodeller.core                - DEBUG     - residual_mass = [4.60877617]
# 21:50:20 - atmodeller.core                - DEBUG     - residual = [-1.95354191  0.95252319  4.60877617]
# 21:50:20 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:20 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126da2b90>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dcfd50>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e3e350>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:20 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:20 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:20 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:20 - atmodeller.core                - DEBUG     - residual_reaction = [-0.44584875  0.22162667]
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000098
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 6152097377919989.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.832907, T = 2500.000000, ppmw = 880.695246
# 21:50:20 - atmodeller.core                - DEBUG     - residual_mass = [1.40980655]
# 21:50:20 - atmodeller.core                - DEBUG     - residual = [-0.44584875  0.22162667  1.40980655]
# 21:50:20 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:20 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dce590>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dcd110>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e12410>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:20 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:20 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:20 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:20 - atmodeller.core                - DEBUG     - residual_reaction = [-2.48689958e-14 -5.55111512e-16]
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000007
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 7495346165570791424.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.500000, T = 2500.000000, ppmw = 682.358044
# 21:50:20 - atmodeller.core                - DEBUG     - residual_mass = [0.86679694]
# 21:50:20 - atmodeller.core                - DEBUG     - residual = [-2.48689958e-14 -5.55111512e-16  8.66796943e-01]
# 21:50:20 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:20 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dcce50>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e18790>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e21210>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:20 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:20 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:20 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:20 - atmodeller.core                - DEBUG     - residual_reaction = [2.22044605e-15 0.00000000e+00]
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000006
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 12120358305151299584.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.500000, T = 2500.000000, ppmw = 682.358044
# 21:50:20 - atmodeller.core                - DEBUG     - residual_mass = [0.86679692]
# 21:50:20 - atmodeller.core                - DEBUG     - residual = [2.22044605e-15 0.00000000e+00 8.66796923e-01]
# 21:50:20 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:20 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126df9b90>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126da3750>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dcffd0>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:20 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:20 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:20 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:20 - atmodeller.core                - DEBUG     - residual_reaction = [-0.02354187  0.01170966]
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 10843396384848939387160216677122048.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.513665, T = 2500.000000, ppmw = 691.619367
# 21:50:20 - atmodeller.core                - DEBUG     - residual_mass = [0.89214845]
# 21:50:20 - atmodeller.core                - DEBUG     - residual = [-0.02354187  0.01170966  0.89214845]
# 21:50:20 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:20 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dff2d0>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dd9c10>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126da16d0>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:20 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:20 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:20 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:20 - atmodeller.core                - DEBUG     - residual_reaction = [-1.78245077e-07 -5.55111512e-16]
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000007
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 7495346165570791424.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.500000, T = 2500.000000, ppmw = 682.358044
# 21:50:20 - atmodeller.core                - DEBUG     - residual_mass = [0.86679694]
# 21:50:20 - atmodeller.core                - DEBUG     - residual = [-1.78245077e-07 -5.55111512e-16  8.66796943e-01]
# 21:50:20 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:20 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e1b110>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e1e190>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e19750>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:20 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:20 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:20 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:20 - atmodeller.core                - DEBUG     - residual_reaction = [-1.40628181e-07 -5.55111512e-16]
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000007
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 7495351019682905088.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.500000, T = 2500.000000, ppmw = 682.358044
# 21:50:20 - atmodeller.core                - DEBUG     - residual_mass = [0.86679694]
# 21:50:20 - atmodeller.core                - DEBUG     - residual = [-1.40628181e-07 -5.55111512e-16  8.66796943e-01]
# 21:50:20 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:20 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dd6a50>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x10b804410>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dd35d0>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:20 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:20 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:20 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:20 - atmodeller.core                - DEBUG     - residual_reaction = [4.48567139e-09 4.48569593e-09]
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000007
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 7495346165570791424.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:20 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.500000, T = 2500.000000, ppmw = 682.358047
# 21:50:21 - atmodeller.core                - DEBUG     - residual_mass = [0.86679695]
# 21:50:21 - atmodeller.core                - DEBUG     - residual = [4.48567139e-09 4.48569593e-09 8.66796953e-01]
# 21:50:21 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:21 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dc3b50>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dce610>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e20b90>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:21 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:21 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:21 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:21 - atmodeller.core                - DEBUG     - residual_reaction = [-0.28138247 -0.28138332]
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 79200942902854367219548160.000000, T = 2500.000000, ppmw = 0.000000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.261569, T = 2500.000000, ppmw = 493.538067
# 21:50:21 - atmodeller.core                - DEBUG     - residual_mass = [0.35001137]
# 21:50:21 - atmodeller.core                - DEBUG     - residual = [-0.28138247 -0.28138332  0.35001137]
# 21:50:21 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:21 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126db4f90>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126ddcb10>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x11dc7d290>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:50:21 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:50:21 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:50:21 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:50:21 - atmodeller.core                - DEBUG     - residual_reaction = [ 0.00184486 -0.23356841]
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000824
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 28132992923.258446, T = 2500.000000, ppmw = 0.000000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.292013, T = 2500.000000, ppmw = 521.468536
# 21:50:21 - atmodeller.core                - DEBUG     - residual_mass = [0.42646481]
# 21:50:21 - atmodeller.core                - DEBUG     - residual = [ 0.00184486 -0.23356841  0.42646481]
# 21:50:21 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:50:21 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e48c90>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126d76e50>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:50:21 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dc8ed0>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
# ...
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.500000, T = 2500.000000, ppmw = 682.358045
# 21:51:05 - atmodeller.core                - DEBUG     - residual_mass = [0.86679678]
# 21:51:05 - atmodeller.core                - DEBUG     - residual = [-9.58182200e-09  1.46238649e-09  8.66796780e-01]
# 21:51:05 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:51:05 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e6c2d0>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126da2410>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126ea1810>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:51:05 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:51:05 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:51:05 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:51:05 - atmodeller.core                - DEBUG     - residual_reaction = [ 0.00060878 -0.35010843]
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 111607428722335650325391080431787206162129272378372444270496879490135856006216543343429006396333089369440470341734139009819144951672207152566948306538725376.000000, T = 2500.000000, ppmw = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.223286, T = 2500.000000, ppmw = 455.992919
# 21:51:05 - atmodeller.core                - DEBUG     - residual_mass = [0.24727252]
# 21:51:05 - atmodeller.core                - DEBUG     - residual = [ 0.00060878 -0.35010843  0.24727252]
# 21:51:05 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:51:05 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dc0990>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e02050>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e2bcd0>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:51:05 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:51:05 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:51:05 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:51:05 - atmodeller.core                - DEBUG     - residual_reaction = [ 0.00060882 -0.35010843]
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 111608022461051276105753937279146707441906442424533304888656862606958352490385210424920650484117790940604794770780973911900813055623258518331732738512519168.000000, T = 2500.000000, ppmw = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.223286, T = 2500.000000, ppmw = 455.992919
# 21:51:05 - atmodeller.core                - DEBUG     - residual_mass = [0.24727252]
# 21:51:05 - atmodeller.core                - DEBUG     - residual = [ 0.00060882 -0.35010843  0.24727252]
# 21:51:05 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:51:05 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126d83a50>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e4a690>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e0dd10>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:51:05 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:51:05 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:51:05 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:51:05 - atmodeller.core                - DEBUG     - residual_reaction = [ 0.00060999 -0.35010842]
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 111607428722335650325391080431787206162129272378372444270496879490135856006216543343429006396333089369440470341734139009819144951672207152566948306538725376.000000, T = 2500.000000, ppmw = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.223286, T = 2500.000000, ppmw = 455.992924
# 21:51:05 - atmodeller.core                - DEBUG     - residual_mass = [0.24727253]
# 21:51:05 - atmodeller.core                - DEBUG     - residual = [ 0.00060999 -0.35010842  0.24727253]
# 21:51:05 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:51:05 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126ebce50>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e13190>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e1a190>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:51:05 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:51:05 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:51:05 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:51:05 - atmodeller.core                - DEBUG     - residual_reaction = [-0.00108095 -0.35062964]
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 31630727767448658622606557385699285041118493998798884979495098930504718767260111513132375394380416384071889019539737133098780742247774143895997103660074537190720264173949867329276723541238550166278911295488.000000, T = 2500.000000, ppmw = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.223018, T = 2500.000000, ppmw = 455.719377
# 21:51:05 - atmodeller.core                - DEBUG     - residual_mass = [0.24652402]
# 21:51:05 - atmodeller.core                - DEBUG     - residual = [-0.00108095 -0.35062964  0.24652402]
# 21:51:05 - atmodeller.core                - INFO      - 1 additional (not fugacity) constraint(s) are necessary to solve the system
# 21:51:05 - atmodeller.core                - INFO      - Row 00: Reaction 0: 1.0 H2 + 0.5 O2 = 1.0 H2O
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e356d0>
#   Hydrogen (H2)	H2(ref)
#     Cp(298.15) = 28.836 J/mol/K
#     S(298.15) = 130.680 J/mol/K
#     [G-H(298.15)]/298.15 = 130.680 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = H2, standard Gibbs energy of formation = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126dd1d10>
#   Oxygen (O2)	O2(ref)
#     Cp(298.15) = 29.376 J/mol/K
#     S(298.15) = 205.147 J/mol/K
#     [G-H(298.15)]/298.15 = 205.147 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = 0 J/mol
#     Delta_fG(298.15) = 0 J/mol
#     log(Kf((298.15)) = 0.000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = O2, standard Gibbs energy of formation = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - ChemicalComponent = <thermochem.janaf.JanafPhase object at 0x126e1cd50>
#   Water (H2O)	H2O1(g)
#     Cp(298.15) = 33.590 J/mol/K
#     S(298.15) = 188.834 J/mol/K
#     [G-H(298.15)]/298.15 = 188.834 J/mol/K
#     H-H(298.15) = 0.000 J/mol/K
#     Delta_fH(298.15) = -241826 J/mol
#     Delta_fG(298.15) = -228582 J/mol
#     log(Kf((298.15)) = 40.047
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - Species = H2O, standard Gibbs energy of formation = -106416.000000
# 21:51:05 - atmodeller.core                - INFO      - Row 01: Setting H2O partial pressure
# 21:51:05 - atmodeller.core                - DEBUG     - Design matrix =
# [[-1.  -0.5  1. ]
#  [ 0.   0.   1. ]]
# 21:51:05 - atmodeller.core                - DEBUG     - RHS vector =
# [ 2.22339717 -0.30103   ]
# 21:51:05 - atmodeller.core                - DEBUG     - residual_reaction = [ 0.00035624 -0.35080122]
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 394506233428327017287007020013350897122469208013775826783044876717316809178242758383088030903208251490304.000000, T = 2500.000000, ppmw = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.222930, T = 2500.000000, ppmw = 455.629365
# 21:51:05 - atmodeller.core                - DEBUG     - residual_mass = [0.24627772]
# 21:51:05 - atmodeller.core                - DEBUG     - residual = [ 0.00035624 -0.35080122  0.24627772]
# 21:51:05 - atmodeller.core                - INFO      - The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# 21:51:05 - atmodeller.core                - INFO      - Retrying with a new randomised initial condition (attempt 10)
# 21:51:05 - atmodeller.core                - DEBUG     - initial_log10_pressures = [1.40783281e-06 1.40783281e-06 1.40783281e-06]
# 21:51:05 - atmodeller.core                - INFO      - Number of function calls = 41
# 21:51:05 - atmodeller.core                - INFO      - Final objective function evaluation = [ 0.00035624 -0.35080122  0.24627772]
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - BasaltH2, f = 0.000000, T = 2500.000000, ppmw = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - NoSolubility, f = 394506233428327017287007020013350897122469208013775826783044876717316809178242758383088030903208251490304.000000, T = 2500.000000, ppmw = 0.000000
# 21:51:05 - atmodeller.thermodynamics      - DEBUG     - BasaltDixonH2O, f = 0.222930, T = 2500.000000, ppmw = 455.629365
# 21:51:05 - atmodeller.core                - INFO      - {'H2': 6.7048403517496945e-56,
#  'H2O': 0.2229301383572343,
#  'O2': 3.94506233428327e+104}
# {'H2': 6.7048403517496945e-56,
#  'O2': 3.94506233428327e+104,
#  'H2O': 0.2229301383572343}

# %% [markdown]
# ### 2. Changing planet properties
#
# We can also change the properties of a planet after it has been created by setting the appropriate attribute. With no arguments to the constructor, a planet with 'default' properties is created and these can be subequently modified by the user.

# %%
planet = Planet()
planet
# Out:
# 21:51:05 - atmodeller.thermodynamics      - INFO      - Creating a new planet
# 21:51:05 - atmodeller.thermodynamics      - INFO      - Mantle mass (kg) = 4208261222595110885130240.000000
# 21:51:05 - atmodeller.thermodynamics      - INFO      - Mantle melt fraction = 1.000000
# 21:51:05 - atmodeller.thermodynamics      - INFO      - Core mass fraction = 0.295335
# 21:51:05 - atmodeller.thermodynamics      - INFO      - Planetary radius (m) = 6371000.000000
# 21:51:05 - atmodeller.thermodynamics      - INFO      - Planetary mass (kg) = 5972000000000000327155712.000000
# 21:51:05 - atmodeller.thermodynamics      - INFO      - Surface temperature (K) = 2000.000000
# 21:51:05 - atmodeller.thermodynamics      - INFO      - Surface gravity (m/s^2) = 9.819973
# 21:51:05 - atmodeller.thermodynamics      - INFO      - Melt Composition = None
# Planet(mantle_mass=4.208261222595111e+24, mantle_melt_fraction=1.0, core_mass_fraction=0.295334691460966, surface_radius=6371000.0, surface_temperature=2000.0, melt_composition=None, planet_mass=5.972e+24, surface_gravity=9.819973426224687)

# %%
planet.surface_temperature = 2800

planet
# Out:
# Planet(mantle_mass=4.208261222595111e+24, mantle_melt_fraction=1.0, core_mass_fraction=0.295334691460966, surface_radius=6371000.0, surface_temperature=2800, melt_composition=None, planet_mass=5.972e+24, surface_gravity=9.819973426224687)
